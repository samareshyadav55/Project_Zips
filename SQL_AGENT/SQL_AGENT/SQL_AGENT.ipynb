# %%
from langchain_community.utilities import SQLDatabase

db = SQLDatabase.from_uri("sqlite:///Chinook.db")

print(db.dialect)
print(db.get_usable_table_names())
print(db.run("SELECT * FROM Artist;"))
# Out:
# sqlite
# ['Album', 'Artist', 'Customer', 'Employee', 'Genre', 'Invoice', 'InvoiceLine', 'MediaType', 'Playlist', 'PlaylistTrack', 'Track']
# ...

# %%
# Analyze through pandas
import pandas as pd
import sqlite3
conn = sqlite3.connect("Chinook.db")
first_table = pd.read_sql("SELECT * FROM Album",conn)
first_table[:5]
# Out:
#    AlbumId                                  Title  ArtistId
# 0        1  For Those About To Rock We Salute You         1
# 1        2                      Balls to the Wall         2
# 2        3                      Restless and Wild         2
# 3        4                      Let There Be Rock         1
# 4        5                               Big Ones         3

# %%
first_table[:10]
# Out:
#    AlbumId                                  Title  ArtistId
# 0        1  For Those About To Rock We Salute You         1
# 1        2                      Balls to the Wall         2
# 2        3                      Restless and Wild         2
# 3        4                      Let There Be Rock         1
# 4        5                               Big Ones         3
# 5        6                     Jagged Little Pill         4
# 6        7                               Facelift         5
# 7        8                         Warner 25 Anos         6
# 8        9         Plays Metallica By Four Cellos         7
# 9       10                             Audioslave         8

# %%
second_table = pd.read_sql("SELECT * FROM Artist",conn)
second_table[:10]
# Out:
#    ArtistId                  Name
# 0         1                 AC/DC
# 1         2                Accept
# 2         3             Aerosmith
# 3         4     Alanis Morissette
# 4         5       Alice In Chains
# 5         6  Antônio Carlos Jobim
# 6         7          Apocalyptica
# 7         8            Audioslave
# 8         9              BackBeat
# 9        10          Billy Cobham

# %%
third_table = pd.read_sql("SELECT * FROM Customer",conn)
third_table[:5]
# Out:
#    CustomerId  FirstName     LastName  \
# 0           1       Luís    Gonçalves
# 1           2     Leonie       Köhler
# 2           3   François     Tremblay
# 3           4      Bjørn       Hansen
# 4           5  František  Wichterlová
#
#                                             Company  \
# 0  Embraer - Empresa Brasileira de Aeronáutica S.A.
# 1                                              None
# 2                                              None
# 3                                              None
# 4                                  JetBrains s.r.o.
#
#                            Address                 City State         Country  \
# 0  Av. Brigadeiro Faria Lima, 2170  São José dos Campos    SP          Brazil
# 1          Theodor-Heuss-Straße 34            Stuttgart  None         Germany
# 2                1498 rue Bélanger             Montréal    QC          Canada
# 3                 Ullevålsveien 14                 Oslo  None          Norway
# ...

# %%
third_table.shape
# Out:
# (59, 13)

# %%
fourth_table = pd.read_sql("SELECT * FROM Employee",conn)
fourth_table[:5]
# Out:
#    EmployeeId LastName FirstName                Title  ReportsTo  \
# 0           1    Adams    Andrew      General Manager        NaN
# 1           2  Edwards     Nancy        Sales Manager        1.0
# 2           3  Peacock      Jane  Sales Support Agent        2.0
# 3           4     Park  Margaret  Sales Support Agent        2.0
# 4           5  Johnson     Steve  Sales Support Agent        2.0
#
#              BirthDate             HireDate              Address      City  \
# 0  1962-02-18 00:00:00  2002-08-14 00:00:00  11120 Jasper Ave NW  Edmonton
# 1  1958-12-08 00:00:00  2002-05-01 00:00:00         825 8 Ave SW   Calgary
# 2  1973-08-29 00:00:00  2002-04-01 00:00:00        1111 6 Ave SW   Calgary
# 3  1947-09-19 00:00:00  2003-05-03 00:00:00     683 10 Street SW   Calgary
# 4  1965-03-03 00:00:00  2003-10-17 00:00:00         7727B 41 Ave   Calgary
#
#   State Country PostalCode              Phone                Fax  \
# ...

# %%
# Lets Build SQL AGENT NOW
# from typing import Any

# from langchain_core.messages import ToolMessage
# from langchain_core.runnables import RunnableLambda, RunnableWithFallbacks
# from langgraph.prebuilt import ToolNode

# %%
from langchain_core.messages import ToolMessage
from langchain_core.runnables import RunnableLambda, RunnableWithFallbacks
from langgraph.prebuilt import ToolNode
from typing import Any
# If a tool call fails,
# the fallback will return an error message to the agent instead of breaking the workflow.
# Accepts a list of tools (these are usually functions or API wrappers).
# Wraps them in a ToolNode, which is a LangGraph component that handles tool execution.

# Adds a fallback using .with_fallbacks(...):
# If the tool raises an exception, the fallback function handle_tool_error() is triggered.
# The exception_key="error" indicates the key in the state where the exception is passed.
def create_tool_node_with_fallback(tools:list) -> RunnableWithFallbacks[Any,dict]:
    return ToolNode(tools).with_fallbacks(
        [RunnableLambda(handle_tool_error)], exception_key="error"
    )

# This function:
# Is triggered when the tool execution fails.
# It receives the current state (a dict holding context including messages and possibly an error).
# Extracts the last tool_calls from the messages.
# Returns a response to the agent containing ToolMessage objects — one for each failed tool call.
def handle_tool_error(state) -> dict:
    error = state.get("error")
    tool_calls = state["messages"][-1].tool_calls
    return {
        "messages": [
            ToolMessage(
                content=f"Error: {repr(error)}\n please fix your mistakes.",
                tool_call_id=tc["id"],
            )
            for tc in tool_calls
        ]
    }

# %%
# This code demonstrates how to use LangChain's SQLDatabaseToolkit to interact with a SQL database using LLM-powered tools. 
# Specifically, it invokes two tools:
# sql_db_list_tables – lists all tables in the database.
# sql_db_schema – gets the schema of a specific table (in this case, the "Artist" table).
# 
from langchain_community.agent_toolkits import SQLDatabaseToolkit
from langchain_openai import ChatOpenAI
import os

llm = ChatOpenAI(
    openai_api_base="https://llmfoundry.straive.com/openai/v1/",
    openai_api_key=f'{os.environ["LLMFOUNDRY_TOKEN"]}:my-test-project',
    model="gpt-4o-mini",
)
toolkit = SQLDatabaseToolkit(db=db, llm=llm)
tools = toolkit.get_tools()

#picks the specific tools from the list of tools SQLDBToolkit
list_tables_tool = next(tool for tool in tools if tool.name == "sql_db_list_tables")
get_schema_tool = next(tool for tool in tools if tool.name == "sql_db_schema")

# %%
tools
# Out:
# [QuerySQLDatabaseTool(description="Input to this tool is a detailed and correct SQL query, output is a result from the database. If the query is not correct, an error message will be returned. If an error is returned, rewrite the query, check the query, and try again. If you encounter an issue with Unknown column 'xxxx' in 'field list', use sql_db_schema to query the correct table fields.", db=<langchain_community.utilities.sql_database.SQLDatabase object at 0x00000248A6E74E60>),
#  InfoSQLDatabaseTool(description='Input to this tool is a comma-separated list of tables, output is the schema and sample rows for those tables. Be sure that the tables actually exist by calling sql_db_list_tables first! Example Input: table1, table2, table3', db=<langchain_community.utilities.sql_database.SQLDatabase object at 0x00000248A6E74E60>),
#  ListSQLDatabaseTool(db=<langchain_community.utilities.sql_database.SQLDatabase object at 0x00000248A6E74E60>),
# ...

# %%
# # This @tool decorator converts a Python function into a 
# # LangChain-compatible tool that can be used by agents or nodes in LangGraph.
# from langchain_core.tools import tool
# @tool
# def db_query_tool(query: str) -> str:
#     """
#     Execute a SQL query against the database and get back the result.
#     If the query is not correct, an error message will be returned.
#     If an error is returned, rewrite the query, check the query, and try again.
#     """
#     result = db.run_no_throw(query)
#     print(result)
#     if not result:
#         return "Error: Query failed. Please rewrite your query and try again."
#     return result

# print(db_query_tool.invoke("SELECT * FROM Artist LIMIT 10;"))

# %%
from langchain_core.tools import tool
from sqlalchemy import text

# @tool
# def db_query_tool(query: str) -> str:
#     """
#     Execute a SQL query against the database and return the full results.
#     """
#     try:
#         with db._engine.connect() as connection:
#             result = connection.execute(text(query))
#             rows = result.fetchall()

#             if not rows:
#                 return "Query succeeded but returned no results."

#             # Optional: Format as table
#             column_names = result.keys()
#             formatted_rows = [dict(zip(column_names, row)) for row in rows]

#             return "\n".join(str(row) for row in formatted_rows)

#     except Exception as e:
#         return f"Error executing query: {str(e)}"

import json

@tool
def db_query_tool(query: str) -> str:
    """
    Execute a SQL query against the database and return results as JSON.
    """
    
    try:
        with db._engine.connect() as connection:
            print(f"[Running query]: {query}")
            result = connection.execute(text(query))
            rows = result.fetchall()
            if not rows:
                return "No results."

            column_names = result.keys()
            formatted_rows = [dict(zip(column_names, row)) for row in rows]

            return json.dumps(formatted_rows, indent=2)  # Structured output

    except Exception as e:
        return f"Error executing query: {str(e)}"

# %%
print(db_query_tool.invoke("SELECT COUNT(*) AS AlbumCount FROM Album WHERE Title LIKE 'B%'"))
# Out:
# [Running query]: SELECT COUNT(*) AS AlbumCount FROM Album WHERE Title LIKE 'B%'
# [
#   {
#     "AlbumCount": 35
#   }
# ]

# %%
from langchain_core.prompts import ChatPromptTemplate

query_check_system = """You are a SQL expert with a strong attention to detail.
Double check the SQLite query for common mistakes, including:
- Using NOT IN with NULL values
- Using UNION when UNION ALL should have been used
- Using BETWEEN for exclusive ranges
- Data type mismatch in predicates
- Properly quoting identifiers
- Using the correct number of arguments for functions
- Casting to the correct data type
- Using the proper columns for joins

If there are any of the above mistakes, rewrite the query. If there are no mistakes, just reproduce the original query.

You will call the appropriate tool to execute the query after running this check."""


#This defines a chat prompt with:
# A system message (rules for behavior).
# A placeholder for dynamic content ({messages}
query_check_prompt = ChatPromptTemplate.from_messages(
    [("system", query_check_system), ("placeholder", "{messages}")]
)

# | (pipe operator): Chains the prompt template into a tool-bound LLM.

# bind_tools(...): Attaches tools to the LLM, allowing it to choose and call a tool based on the prompt.

# tool_choice="required": The LLM must pick one of the listed tools (in this case, only db_query_tool).
query_check = query_check_prompt | llm.bind_tools(
    [db_query_tool], tool_choice="required"
)

query_check.invoke({"messages": [("user", "SELECT * FROM Artist LIMIT 10;")]})
# Out:
# AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_UqFUWuEqCLeEliIejz5ezbz8', 'function': {'arguments': '{"query":"SELECT * FROM Artist LIMIT 10;"}', 'name': 'db_query_tool'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 187, 'total_tokens': 209, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_34a54ae93c', 'id': 'chatcmpl-Bk7KrK8T7CNbeM5mgT8PP35nnvjTW', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run--6668d2be-0f62-4a38-b589-7c9233decc58-0', tool_calls=[{'name': 'db_query_tool', 'args': {'query': 'SELECT * FROM Artist LIMIT 10;'}, 'id': 'call_UqFUWuEqCLeEliIejz5ezbz8', 'type': 'tool_call'}], usage_metadata={'input_tokens': 187, 'output_tok
# ...

# %%
from typing_extensions import TypedDict
from typing import Annotated, Literal
from langgraph.graph.message import AnyMessage, add_messages

# State: Defines the state object passed between nodes in the graph.
# messages: A list of messages (e.g., user messages, tool calls, model replies).
# add_messages: A LangGraph utility that automatically appends new messages to the state.


# 
class State(TypedDict):
    messages: Annotated[list[AnyMessage], add_messages]

## Graph Initialization
# Creates a new LangGraph where each node will receive and return a State.
from langgraph.graph import END, StateGraph, START
workflow = StateGraph(State)

from langchain_core.messages import AIMessage
# This function simulates a tool call request:
# It returns an AIMessage that doesn’t say anything (content=""), but includes a tool_calls field.
# This tool call instructs the agent (or tool node) to run sql_db_list_tables with no arguments.
# This message will be processed by a ToolNode or similar handler in the graph.

def first_tool_call(state: State) -> dict[str, list[AIMessage]]:
    return {
        "messages": [
            AIMessage(
                content="",
                tool_calls=[
                    {
                        "name": "sql_db_list_tables",
                        "args": {},
                        "id": "tool_abcd123",
                    }
                ],
            )
        ]
    }

# Takes the latest message in the conversation.
# Passes it to query_check, which is your tool-bound LLM that:
# Checks for SQL mistakes.
# Fixes the query if needed.
# Calls db_query_tool to run it.
# Wraps the result in a list of AIMessage and returns it to be added to the state.

def model_check_query(state: State) -> dict[str, list[AIMessage]]:
    return {"messages": [query_check.invoke({"messages": [state["messages"][-1]]})]}

workflow.add_node("first_tool_call", first_tool_call)

# Add nodes for the first two tools
workflow.add_node(
    "list_tables_tool", create_tool_node_with_fallback([list_tables_tool])
)
workflow.add_node("get_schema_tool", create_tool_node_with_fallback([get_schema_tool]))

# Add a node for a model to choose the relevant tables based on the question and available tables
model_get_schema = llm.bind_tools(
    [get_schema_tool]
)
workflow.add_node(
    "model_get_schema",
    lambda state: {
        "messages": [model_get_schema.invoke(state["messages"])],
    },
)

# %%
from pydantic import BaseModel, Field
class SubmitFinalAnswer(BaseModel):
    """Submit the final answer to the user based on the query results."""

    final_answer: str = Field(..., description="The final answer to the user")


# Add a node for a model to generate a query based on the question and schema
query_gen_system = """You are a SQL expert with a strong attention to detail.

Given an input question, output a syntactically correct SQLite query to run, then look at the results of the query and return the answer.

DO NOT call any tool besides SubmitFinalAnswer to submit the final answer.

When generating the query:

Output the SQL query that answers the input question without a tool call.

Unless the user specifies a specific number of examples they wish to obtain, always limit your query to at most 5 results.
You can order the results by a relevant column to return the most interesting examples in the database.
Never query for all the columns from a specific table, only ask for the relevant columns given the question.

If you get an error while executing a query, rewrite the query and try again.

If you get an empty result set, you should try to rewrite the query to get a non-empty result set.
NEVER make stuff up if you don't have enough information to answer the query... just say you don't have enough information.

If you have enough information to answer the input question, simply invoke the appropriate tool to submit the final answer to the user.

DO NOT make any DML statements (INSERT, UPDATE, DELETE, DROP etc.) to the database."""
query_gen_prompt = ChatPromptTemplate.from_messages(
    [("system", query_gen_system), ("placeholder", "{messages}")]
)
query_gen = query_gen_prompt | llm.bind_tools(
    [SubmitFinalAnswer]
)


def query_gen_node(state: State):
    message = query_gen.invoke(state)

    # Sometimes, the LLM will hallucinate and call the wrong tool. We need to catch this and return an error message.
    tool_messages = []
    if message.tool_calls:
        for tc in message.tool_calls:
            if tc["name"] != "SubmitFinalAnswer":
                tool_messages.append(
                    ToolMessage(
                        content=f"Error: The wrong tool was called: {tc['name']}. Please fix your mistakes. Remember to only call SubmitFinalAnswer to submit the final answer. Generated queries should be outputted WITHOUT a tool call.",
                        tool_call_id=tc["id"],
                    )
                )
    else:
        tool_messages = []
    return {"messages": [message] + tool_messages}


workflow.add_node("query_gen", query_gen_node)

# Add a node for the model to check the query before executing it
workflow.add_node("correct_query", model_check_query)

# Add node for executing the query
workflow.add_node("execute_query", create_tool_node_with_fallback([db_query_tool]))


# Define a conditional edge to decide whether to continue or end the workflow
def should_continue(state: State) -> Literal[END, "correct_query", "query_gen"]:
    messages = state["messages"]
    last_message = messages[-1]
    # If there is a tool call, then we finish
    if getattr(last_message, "tool_calls", None):
        return END
    if last_message.content.startswith("Error:"):
        return "query_gen"
    else:
        return "correct_query"


# Specify the edges between the nodes
workflow.add_edge(START, "first_tool_call")
workflow.add_edge("first_tool_call", "list_tables_tool")
workflow.add_edge("list_tables_tool", "model_get_schema")
workflow.add_edge("model_get_schema", "get_schema_tool")
workflow.add_edge("get_schema_tool", "query_gen")
workflow.add_conditional_edges(
    "query_gen",
    should_continue,
)
workflow.add_edge("correct_query", "execute_query")
workflow.add_edge("execute_query", "query_gen")

# Compile the workflow into a runnable
app = workflow.compile()

# %%
result = app.stream(
    {"messages": [("user", "How may Album that start with letter B")]}
)

# %%
question = 'How may Album that start with letter B'

# %%
for step in app.stream({"messages": [{"role": "user", "content": question}]}, stream_mode="values"):
    for msg in step["messages"]:
        if msg.type == "tool":
            print("🔧 TOOL CALLED:", msg.tool_call_id)
            print("🔍 QUERY SENT:\n", msg.content)
    step["messages"][-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# How may Album that start with letter B
# ================================== Ai Message ==================================
# Tool Calls:
#   sql_db_list_tables (tool_abcd123)
#  Call ID: tool_abcd123
#   Args:
# 🔧 TOOL CALLED: tool_abcd123
# 🔍 QUERY SENT:
#  Album, Artist, Customer, Employee, Genre, Invoice, InvoiceLine, MediaType, Playlist, PlaylistTrack, Track
# ================================= Tool Message =================================
# Name: sql_db_list_tables
#
# Album, Artist, Customer, Employee, Genre, Invoice, InvoiceLine, MediaType, Playlist, PlaylistTrack, Track
# 🔧 TOOL CALLED: tool_abcd123
# 🔍 QUERY SENT:
#  Album, Artist, Customer, Employee, Genre, Invoice, InvoiceLine, MediaType, Playlist, PlaylistTrack, Track
# ================================== Ai Message ==================================
# Tool Calls:
#   sql_db_schema (call_YoAMWw6GDFiQO2Gp8ib7jx5m)
# ...

# %%
for event in app.stream(
    {"messages": [("user", "How may Album that start with letter B")]}
):
    print(event)
# Out:
# {'first_tool_call': {'messages': [AIMessage(content='', additional_kwargs={}, response_metadata={}, id='c2d17e4b-4948-4cd0-a5f1-a1bdd04fa647', tool_calls=[{'name': 'sql_db_list_tables', 'args': {}, 'id': 'tool_abcd123', 'type': 'tool_call'}])]}}
# {'list_tables_tool': {'messages': [ToolMessage(content='Album, Artist, Customer, Employee, Genre, Invoice, InvoiceLine, MediaType, Playlist, PlaylistTrack, Track', name='sql_db_list_tables', id='b5f182de-dc1e-4280-b62c-b825ca306487', tool_call_id='tool_abcd123')]}}
# ...

# %%
question = "How may Album that start with letter B"

for step in app.stream(
    {"messages": [{"role": "user", "content": question}]},
    stream_mode="values",
):
    step["messages"][-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# How may Album that start with letter B
# ================================== Ai Message ==================================
# Tool Calls:
#   sql_db_list_tables (tool_abcd123)
#  Call ID: tool_abcd123
#   Args:
# ================================= Tool Message =================================
# Name: sql_db_list_tables
#
# Album, Artist, Customer, Employee, Genre, Invoice, InvoiceLine, MediaType, Playlist, PlaylistTrack, Track
# ================================== Ai Message ==================================
# Tool Calls:
#   sql_db_schema (call_YoAMWw6GDFiQO2Gp8ib7jx5m)
#  Call ID: call_YoAMWw6GDFiQO2Gp8ib7jx5m
#   Args:
#     table_names: Album
# ================================= Tool Message =================================
# Name: sql_db_schema
#
#
# CREATE TABLE "Album" (
# 	"AlbumId" INTEGER NOT NULL,
# 	"Title" NVARCHAR(160) NOT NULL,
# 	"ArtistId" INTEGER NOT NULL,
# 	PRIMARY KEY ("AlbumId"),
# ...

# %%
from IPython.display import Image, display
from langchain_core.runnables.graph import MermaidDrawMethod

display(
    Image(
        app.get_graph().draw_mermaid_png(
            draw_method=MermaidDrawMethod.PYPPETEER  # ✅ Use local rendering
        )
    )
)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[38], line 6
#       1 from IPython.display import Image, display
#       2 from langchain_core.runnables.graph import MermaidDrawMethod
#       4 display(
#       5     Image(
# ----> 6         app.get_graph().draw_mermaid_png(
#       7             draw_method=MermaidDrawMethod.PYPPETEER  # ✅ Use local rendering
#       8         )
#       9     )
#      10 )
#
# File c:\Users\e430225\AppData\Local\anaconda3\Lib\site-packages\langchain_core\runnables\graph.py:693, in Graph.draw_mermaid_png(self, curve_style, node_colors, wrap_label_n_words, output_file_path, draw_method, background_color, padding, max_retries, retry_delay, frontmatter_config)
#     685 from langchain_core.runnables.graph_mermaid import draw_mermaid_png
#     687 mermaid_syntax = self.draw_mermaid(
#     688     curve_style=curve_style,
# ...
